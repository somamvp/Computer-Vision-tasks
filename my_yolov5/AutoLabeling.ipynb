# %% [markdown]
# # Auto Labeling Experiments

# %% [markdown]
# ## 1. Wesee data quality upgrade through AutoLabeling

# %%
# Wesee AL1
# !python train.py --weight weseel_RAplus2.pt --name weseel_AL1_ --data wesee_AL1.yaml --epochs 40 --rect --img 640 --batch 16
# Out:
# train: weights=weseel_RAplus2.pt, cfg=, data=wesee_AL1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=weseel_AL1_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Wesee AL3
# !python train.py --weight weseel_AL1.pt --name weseel_AL3_ --data wesee_AL3.yaml --epochs 40 --rect --img 640 --batch 16
# Out:
# train: weights=weseel_AL1.pt, cfg=, data=wesee_AL3.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=weseel_AL3_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Wesee AL3
# !python train.py --weight weseel_AL1.pt --name weseel_ALtest_ --data wesee_AL3.yaml --epochs 2 --rect --img 640 --batch 32
# Out:
# train: weights=weseel_AL1.pt, cfg=, data=wesee_AL3.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2, batch_size=32, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=weseel_ALtest_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# detect for ppt images
# !python detect.py --weights weseel_AL3.pt --img 640 --conf 0.4 --source data/sample --data data/wesee_RA.yaml
# Out:
# detect: weights=['weseel_AL3.pt'], source=data/sample, data=data/wesee_RA.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# Fusing layers...
# Model summary: 367 layers, 46248288 parameters, 0 gradients, 108.1 GFLOPs
# image 1/46 /home/soma2/MVP/voyager-Vision-task/my_yolov5/data/sample/89Out_Day_Left_20211021_00109.jpg: 384x640 Done. (0.016s)
# image 2/46 /home/soma2/MVP/voyager-Vision-task/my_yolov5/data/sample/89Out_Day_Left_20211021_00144.jpg: 384x640 Done. (0.011s)
# ...
