# %%
# !python detect.py --weights basicv5.pt --source ../../dataset/source_hard --name src_hard --data data/wesee_AL1.yaml --img-size 640 --conf-thres 0.25 --iou-thres 0.65
# Out:
# detect: weights=['basicv5.pt'], source=../../dataset/source_hard, data=data/wesee_AL1.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.65, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=src_hard, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-9-26 Python-3.9.13 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# Fusing layers...
# YOLOv5m_wesee summary: 290 layers, 20861016 parameters, 0 gradients
# image 1/33 /home/soma1/MVP/dataset/source_hard/221025_16:18:45.94_Session1.jpg: 640x480 1 Zebra_Cross, 1 R_Signal, Done. (0.018s)
# image 2/33 /home/soma1/MVP/dataset/source_hard/221025_16:18:46.95_Session2.jpg: 640x480 1 Zebra_Cross, 1 R_Signal, Done. (0.014s)
# ...

# %%
# !python detect.py --weights basicv5.pt --source ../../dataset/source --name weseev5_QC --data data/wesee_AL1.yaml --img-size 640 --conf-thres 0.25 --iou-thres 0.65
# Out:
# detect: weights=['basicv5.pt'], source=../../dataset/source, data=data/wesee_AL1.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.65, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=weseev5_QC, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-9-26 Python-3.9.13 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# Fusing layers...
# YOLOv5m_wesee summary: 290 layers, 20861016 parameters, 0 gradients
# image 1/105 /home/soma1/MVP/dataset/source/264108736.jpg: 640x448 Done. (0.014s)
# image 2/105 /home/soma1/MVP/dataset/source/394854395.jpg: 480x640 Done. (0.014s)
# image 3/105 /home/soma1/MVP/dataset/source/432259479.jpg: 640x480 Done. (0.017s)
# image 4/105 /home/soma1/MVP/dataset/source/496995352.jpg: 480x640 1 Zebra_Cross, Done. (0.016s)
# ...
