# %% [markdown]
# # RA 통합라벨링 Training
# ## 0. 필수 Arguments
# ```shell
#     (변동)
#     --weight  yolov5l.pt
#     --name  dobol_RA2_
#     --data  dobo_RA.yaml
#     --epochs  10
#     (고정)
#     --hyp data/hyps/hyp.voyager.yaml
#     --rect
#     --img  640
#     --batch  16
#  ```

# %% [markdown]
# # 1. Dobo set Train
# Train \*.pt through "!python train.py" python script with options<br>

# %%
# Dobo large model RA
# !python train.py --weights yolov5l.pt --name dobo_l_RA1 --data dobo_RA.yaml --epochs 20 --rect --img 640 --batch 16 #--hyp data/hyps/hyp.voyager.yaml
# Out:
# train: weights=yolov5l.pt, cfg=, data=dobo_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=dobo_l_RA1, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# Traceback (most recent call last):
#   File "train.py", line 670, in <module>
#     main(opt)
#   File "train.py", line 540, in main
#     check_file(opt.data), check_yaml(opt.cfg), check_yaml(opt.hyp), str(opt.weights), str(opt.project)  # checks
#   File "/home/soma2/MVP/voyager-Vision-task/my_yolov5/utils/general.py", line 443, in check_file
#     assert len(files), f'File not found: {file}'  # assert file was found
# AssertionError: File not found: dobo_RA.yaml

# %%
# Dobo large model RA2
# !python train.py
--weights dobol_RA1.pt --name dobo_l_RA2 --data dobo_RA.yaml --epochs 60
--hyp data/hyps/hyp.voyager.yaml --rect --img 640 --batch 16

# %% [markdown]
# # 2. Chair set Train
# Train \*.pt through "!python train.py" python script with options<br>

# %%
# Chair large model RA1
# !python train.py --weights yolov5l.pt --name chairl_RA1_ --data chair_RA.yaml --epochs 20 --rect --img 640 --batch 16 # --hyp data/hyps/hyp.voyager.yaml
# Out:
# train: weights=yolov5l.pt, cfg=, data=chair_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=chairl_RA1_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=27
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1    172320  models.yolo.Detect                      [27, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 468 layers, 46278304 parameters, 46278304 gradients, 108.7 GFLOPs
#
# Transferred 607/613 items from yolov5l.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 101 weight (no decay), 104 weight, 104 bias
# WARNING: --rect is incompatible with DataLoader shuffle, setting shuffle=False
# train: Scanning '/home/soma2/MVP/dataset/Chair_parsed/train/labels' images and l
# train: New cache created: /home/soma2/MVP/dataset/Chair_parsed/train/labels.cache
# val: Scanning '/home/soma2/MVP/dataset/Chair_parsed/val/labels' images and label
# val: New cache created: /home/soma2/MVP/dataset/Chair_parsed/val/labels.cache
# Plotting labels to runs/train/chairl_RA1_2/labels.jpg...
#
# AutoAnchor: 4.57 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/chairl_RA1_2
# Starting training for 20 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/19     5.94G    0.0685   0.02631   0.04674        60       640:  69%|███

# %%
# Chair large model RA2
# !python train.py --weights chairl_RA1.pt --name chairl_RA2_ --data chair_RA.yaml --epochs 60 --hyp data/hyps/hyp.voyager.yaml --rect --img 640 --batch 16

# %% [markdown]
# # 3. Wesee set Train
# Train \*.pt through "!python train.py" python script with options<br>

# %%
# Wesee large model RA
# !python train.py
--weights yolov5l.pt --name wesee_l_RA1 --data wesee_RA.yaml --epochs 20
--img 640 --rect --batch 16 --hyp data/hyps/hyp.voyager.yaml
# Out:
# train: weights=yolov5l.pt, cfg=, data=wesee_RA.yaml, hyp=data/hyps/hyp.voyager.yaml, epochs=20, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=wesee_l_RA1, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.837, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=1.5, hsv_h=0.015, hsv_s=0.4, hsv_v=0.2, degrees=0.0, translate=0.1, scale=0.8, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.1, copy_paste=0.1
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=27
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1    172320  models.yolo.Detect                      [27, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 468 layers, 46278304 parameters, 46278304 gradients, 108.7 GFLOPs
#
# Transferred 607/613 items from yolov5l.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 101 weight (no decay), 104 weight, 104 bias
# WARNING: --rect is incompatible with DataLoader shuffle, setting shuffle=False
# train: Scanning '/home/soma2/MVP/dataset/Wesee_parsed/train/labels' images and l
# train: New cache created: /home/soma2/MVP/dataset/Wesee_parsed/train/labels.cache
# val: Scanning '/home/soma2/MVP/dataset/Wesee_parsed/val/labels' images and label
# val: New cache created: /home/soma2/MVP/dataset/Wesee_parsed/val/labels.cache
# Plotting labels to runs/train/wesee_l_RA1/labels.jpg...
#
# AutoAnchor: 2.79 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/wesee_l_RA1
# Starting training for 20 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/19     5.94G   0.04741  0.001783  0.003126         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.946      0.282       0.31       0.23
# Current epoch : 0
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/19     6.86G   0.03138  0.001535  0.001217         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.974      0.294      0.362      0.272
# Current epoch : 1
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/19     6.86G   0.02994  0.001344  0.001074         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.978      0.295      0.358      0.273
# Current epoch : 2
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/19     6.86G   0.02767  0.001219 0.0009352         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.975      0.298      0.381      0.301
# Current epoch : 3
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/19     6.86G   0.02555  0.001091 0.0007855         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.978      0.303      0.383      0.312
# Current epoch : 4
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/19     6.86G   0.02386 0.0009821 0.0006786         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.676      0.345      0.553      0.421
# Current epoch : 5
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/19     6.86G   0.02255 0.0008887 0.0006003         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.732      0.451      0.605      0.467
# Current epoch : 6
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/19     6.86G   0.02171 0.0007982 0.0005465         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.664      0.651      0.736      0.561
# Current epoch : 7
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/19     6.86G   0.02071 0.0007384 0.0005109         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.665      0.732      0.784      0.606
# Current epoch : 8
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/19     6.86G   0.01965 0.0006835 0.0004891         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.707      0.788      0.806      0.626
# Current epoch : 9
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/19     6.86G   0.01908 0.0006388 0.0004599         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.729      0.838      0.833      0.656
# Current epoch : 10
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/19     6.86G   0.01851 0.0006063   0.00044         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.738      0.876      0.855      0.676
# Current epoch : 11
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/19     6.86G   0.01796 0.0005834 0.0004182         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.756      0.888      0.868      0.691
# Current epoch : 12
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/19     6.86G   0.01724 0.0005563 0.0003621         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.782      0.903      0.883      0.706
# Current epoch : 13
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/19     6.86G    0.0168   0.00054 0.0003308         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.776      0.896      0.884      0.709
# Current epoch : 14
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/19     6.86G   0.01643 0.0005256 0.0003031         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.777       0.91      0.885      0.711
# Current epoch : 15
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/19     6.86G   0.01588  0.000515 0.0002649         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.792      0.908        0.9       0.73
# Current epoch : 16
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/19     6.86G   0.01553 0.0004968 0.0002424         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.796      0.916      0.904      0.736
# Current epoch : 17
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/19     6.86G   0.01506 0.0004836 0.0002237         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.787      0.919        0.9      0.734
# Current epoch : 18
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/19     6.86G   0.01452  0.000472  0.000202         9       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.798      0.922      0.906       0.74
# Current epoch : 19
#
# 20 epochs completed in 3.464 hours.
# Optimizer stripped from runs/train/wesee_l_RA1/weights/last.pt, 93.1MB
# Optimizer stripped from runs/train/wesee_l_RA1/weights/best.pt, 93.1MB
#
# Validating runs/train/wesee_l_RA1/weights/best.pt...
# Fusing layers...
# Model summary: 367 layers, 46248288 parameters, 0 gradients, 108.1 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       3625       4714      0.798      0.922      0.906       0.74
#          Zebra_Cross       3625       3625      0.944      0.974      0.982      0.916
#             R_Signal       3625        787      0.726      0.931      0.886      0.663
#             G_Signal       3625        302      0.725      0.861      0.849      0.643
# Results saved to runs/train/wesee_l_RA1

# %%
# Wesee large model RA2
# !python train.py --weight weseel_RA1.pt --name weseel_RA2_ --data wesee_RA.yaml --epochs 60 --rect --img 640 --batch 16

# %% [markdown]
# # 4. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %%
# Wesee_80 val
# !python val.py --weights wesee_80.pt --data wesee.yaml --img 640 --iou 0.65 --half

# %% [markdown]
# # 5. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source ../data/images
display.Image(filename='runs/detect/exp/zidane.jpg', width=600)

# %%
# My Inference
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source ../data/images  --data ../data/coco128.yaml

# %%
# My Inference
# !python detect.py --weights yolov5m.pt --img 640 --conf 0.25 --source ../data/images  --data ../data/coco128.yaml
