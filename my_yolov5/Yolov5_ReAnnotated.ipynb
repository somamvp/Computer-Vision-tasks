# %% [markdown]
# # RA 통합라벨링 Training
# ## 0. 필수 Arguments
# ```shell
#     (변동)
#     --weight  yolov5l.pt
#     --name  dobol_RA2_
#     --data  dobo_RA.yaml
#     --epochs  10
#     (고정)
#     --hyp data/hyps/hyp.voyager.yaml
#     --rect
#     --img  640
#     --batch  16
#  ```

# %% [markdown]
# # 1. Dobo set Train
# Train \*.pt through "!python train.py" python script with options<br>

# %%
# Dobo large model RA
# !python train.py --weight yolov5l.pt --name dobol_RA1_ --data dobo_RA.yaml --epochs 15 --rect --img 640 --batch 16 --save-period 2
# Out:
# train: weights=yolov5l.pt, cfg=, data=dobo_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=dobol_RA1, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Dobo large model RA2
# !python train.py --weight dobol_RA1.pt --name dobol_RA2_ --data dobo_RA.yaml --epochs 30 --rect --img 640 --batch 16 --save-period 2
# Out:
# train: weights=dobol_RA1.pt, cfg=, data=dobo_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=dobol_RA2_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=2, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %% [markdown]
# # 2. Chair set Train
# Train \*.pt through "!python train.py" python script with options<br>

# %%
# Chair large model RA1
# !python train.py --weight yolov5l.pt --name chairl_RA1_ --data chair_RA.yaml --epochs 20 --rect --img 640 --batch 16
# Out:
# train: weights=yolov5l.pt, cfg=, data=chair_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=chairl_RA1_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Chair large model RA2
# !python train.py --weight chairl_RA1.pt --name chairl_RA2_ --data chair_RA.yaml --epochs 60 --rect --img 640 --batch 16
# Out:
# train: weights=chairl_RA1.pt, cfg=, data=chair_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=chairl_RA2_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Chair large model RA3
# !python train.py --weight chairl_RA2.pt --name chairl_RA3_ --data chair_RA.yaml --epochs 60 --rect --img 640 --batch 16
# Out:
# train: weights=chairl_RA2.pt, cfg=, data=chair_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=chairl_RA3_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %% [markdown]
# # 3. Wesee set Train
# Train \*.pt through "!python train.py" python script with options<br>

# %%
# Wesee large model RA
# !python train.py --weight yolov5l.pt --name wesee_l_RA1 --data wesee_RA.yaml --epochs 20 --img 640 --rect --batch 16 #--hyp data/hyps/hyp.voyager.yaml

# %%
# Wesee large model RA2
# !python train.py --weight weseel_RA1.pt --name weseel_RA2_ --data wesee_RA.yaml --epochs 60 --rect --img 640 --batch 16
# Out:
# train: weights=weseel_RA1.pt, cfg=, data=wesee_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=weseel_RA2_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Wesee large model RA3
# !python train.py --weight weseel_RA2.pt --name weseel_RA3_ --data wesee_RA.yaml --epochs 30 --rect --img 640 --batch 16
# Out:
# train: weights=weseel_RA2.pt, cfg=, data=wesee_RA.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=weseel_RA3_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Wesee large model RA4 plus
# !python train.py --weight weseel_RA3.pt --name weseel_RAplus1_ --data wesee_RAplus.yaml --epochs 40 --rect --img 640 --batch 16
# Out:
# train: weights=weseel_RA3.pt, cfg=, data=wesee_RAplus.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=weseel_RA4plus_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %%
# Wesee large model RA4 plus
# !python train.py --weight weseel_RAplus1.pt --name weseel_RAplus2_ --data wesee_RAplus.yaml --epochs 50 --rect --img 640 --batch 16
# Out:
# train: weights=weseel_RAplus1.pt, cfg=, data=wesee_RAplus.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=weseel_RAplus2_, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-8-4 Python-3.7.2 torch-1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265MiB)
#
# ...

# %% [markdown]
# # 4. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %%
# Wesee_80 val
# !python val.py --weights wesee_80.pt --data wesee.yaml --img 640 --iou 0.65 --half

# %% [markdown]
# # 5. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source ../data/images
display.Image(filename='runs/detect/exp/zidane.jpg', width=600)

# %%
# My Inference
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source ../data/images  --data ../data/coco128.yaml

# %%
# My Inference
# !python detect.py --weights yolov5m.pt --img 640 --conf 0.25 --source ../data/images  --data ../data/coco128.yaml
