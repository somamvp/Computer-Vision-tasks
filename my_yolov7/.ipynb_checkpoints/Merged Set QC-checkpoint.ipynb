# %%
# QC for Basic
# !python detect.py --weights basic7_ind2.pt --source ../../dataset/source --name basic_QC --img-size 640 --conf-thres 0.25 --iou-thres 0.65
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.65, name='basic_QC', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='../../dataset/source', update=False, view_img=False, weights=['basic7_ind2.pt'])
# YOLOR 🚀 8a5a81b torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36622016 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#  The image with the result is saved in: runs/detect/basic_QC/264108736.jpg
#  The image with the result is saved in: runs/detect/basic_QC/394854395.jpg
#  The image with the result is saved in: runs/detect/basic_QC/432259479.jpg
#  The image with the result is saved in: runs/detect/basic_QC/496995352.jpg
#  The image with the result is saved in: runs/detect/basic_QC/5841516.jpg
#  The image with the result is saved in: runs/detect/basic_QC/829365.jpg
#  The image with the result is saved in: runs/detect/basic_QC/DC0106_2020-11-19_132652_0P.jpg
#  The image with the result is saved in: runs/detect/basic_QC/KakaoTalk_20220916_113653417_01.jpg
#  The image with the result is saved in: runs/detect/basic_QC/KakaoTalk_20220916_113653417_09.jpg
#  The image with the result is saved in: runs/detect/basic_QC/KakaoTalk_20220916_113653417_12.jpg
#  The image with the result is saved in: runs/detect/basic_QC/KakaoTalk_20220916_113724857_03.jpg
#  The image with the result is saved in: runs/detect/basic_QC/KakaoTalk_20220916_113724857_07.jpg
#  The image with the result is saved in: runs/detect/basic_QC/KakaoTalk_20220916_113724857_13.jpg
#  The image with the result is saved in: runs/detect/basic_QC/KakaoTalk_20220916_113727449.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_000304.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_000327.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_000332.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_000399.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_000475.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_005400.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_005528.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_007582.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_007761.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_007855.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_007873.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_007950.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_008003.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_008112.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_008124.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_KSC_008150.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_007588.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_019020.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_104954.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_114558.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_210062_B078098.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_B013252.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_B055095.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_B062576.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000014.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000020.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000026.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000048.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000174.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000195.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000220.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000232.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000276.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000366.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000373.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000394.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000400.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000510.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000527.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000530.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000541.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000561.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000583.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000609.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000626.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000631.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_000645.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_001184.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_001780.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_001815.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_001833.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_001988.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_002729.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_002805.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_002842.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_002847.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_002849.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_002853.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_003440.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_003505.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_003814.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_003838.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_003859.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_003859_rot.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_004564.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_004789.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_004789_rot.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_004868.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_005019.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_005056.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_005142.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_010265.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_012043.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_012221.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_012226.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_012740.jpg
#  The image with the result is saved in: runs/detect/basic_QC/MP_SEL_MIN_014014.jpg
#  The image with the result is saved in: runs/detect/basic_QC/[Train Set]MP_SEL_117609.jpg
#  The image with the result is saved in: runs/detect/basic_QC/[Train Set]MP_SEL_117613.jpg
#  The image with the result is saved in: runs/detect/basic_QC/[Train Set]MP_SEL_117908.jpg
#  The image with the result is saved in: runs/detect/basic_QC/[Train Set]MP_SEL_250955_B108150.jpg
#  The image with the result is saved in: runs/detect/basic_QC/[Train Set]MP_SEL_251073_B108234.jpg
#  The image with the result is saved in: runs/detect/basic_QC/[Train Set]MP_SEL_251207_B108341.jpg
#  The image with the result is saved in: runs/detect/basic_QC/[Train Set]MP_SEL_251527_B108541.jpg
#  The image with the result is saved in: runs/detect/basic_QC/폴리텍대학_Day20211124_17689.jpg
#  The image with the result is saved in: runs/detect/basic_QC/폴리텍대학_Day20211124_18474.jpg
#  The image with the result is saved in: runs/detect/basic_QC/폴리텍대학_Day20211124_19266.jpg
#  The image with the result is saved in: runs/detect/basic_QC/폴리텍대학_Day20211124_19729.jpg
#  The image with the result is saved in: runs/detect/basic_QC/폴리텍대학_Day20211124_20902.jpg
#  The image with the result is saved in: runs/detect/basic_QC/폴리텍대학_Day20211124_20973.jpg
#  The image with the result is saved in: runs/detect/basic_QC/폴리텍대학_Day20211124_20983.jpg
# Done. (3.940s)

# %%
# QC for Extra
# !python detect.py --weights extra7_fin.pt --source ../../dataset/source --name extra_QC --img-size 640 --conf-thres 0.25 --iou-thres 0.65

# %%
# QC for Extended
# !python detect.py --weights extended7_fin.pt --source ../../dataset/source --name extended_QC --img-size 640 --conf-thres 0.25 --iou-thres 0.65
