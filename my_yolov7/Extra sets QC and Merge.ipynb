# %%
# QC for dobo
# !python detect.py --weights dobo7_fin.pt --source ../../dataset/source --name dobo_QC --img-size 640 --conf-thres 0.25 --iou-thres 0.65
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.65, name='dobo_QC', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='../../dataset/source', update=False, view_img=False, weights=['dobo7_fin.pt'])
# YOLOR 🚀 0dff5d7 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36622016 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#  The image with the result is saved in: runs/detect/dobo_QC2/264108736.jpg
#  The image with the result is saved in: runs/detect/dobo_QC2/394854395.jpg
#  The image with the result is saved in: runs/detect/dobo_QC2/432259479.jpg
#  The image with the result is saved in: runs/detect/dobo_QC2/496995352.jpg
# ...

# %%
# Val for chair7_fin.pt
# !python test.py --weights chair7_fin.pt --data chair.yaml --img-size 640 --batch-size 8
# Out:
# Namespace(augment=False, batch_size=8, conf_thres=0.001, data='./data/chair.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['chair7_fin.pt'])
# YOLOR 🚀 0dff5d7 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36622016 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# val: Scanning '../../dataset/Chair_np/val/labels.cache' images and labels... 1979 found, 0 missing, 362 empty, 0 corrupted: 100%|█| 1979/1979 [00:00<00:00, 13788251.85it/s]
# ...

# %%
# QC for chair
# !python detect.py --weights chair7_fin.pt --source ../../dataset/source --name chair_QC --img-size 640 --conf-thres 0.25 --iou-thres 0.65
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.65, name='chair_QC', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='../../dataset/source', update=False, view_img=False, weights=['chair7_fin.pt'])
# YOLOR 🚀 0dff5d7 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36622016 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#  The image with the result is saved in: runs/detect/chair_QC2/264108736.jpg
#  The image with the result is saved in: runs/detect/chair_QC2/394854395.jpg
#  The image with the result is saved in: runs/detect/chair_QC2/432259479.jpg
#  The image with the result is saved in: runs/detect/chair_QC2/496995352.jpg
# ...

# %%
# Extra set 통합 러닝
# 데이터셋 23종 + Braille
# !python train.py --epoch 10 --data data/voyagerExtra.yaml --weights chair7_fin.pt --name voyagerExtra_ind1_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 8a5a81b torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/voyagerExtra.yaml', device='', entity=None, epochs=10, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='voyagerExtra_ind1_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/voyagerExtra_ind1_3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='chair7_fin.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
