# %% [markdown]
# # Yolov7

# %% [markdown]
# ## 1. Wesee

# %%
# First training wesee newparsed
# !python train.py  --epoch 10 --data data/wesee.yaml --weights yolov7.pt --name wesee7_ind1_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 32
# Out:
# YOLOR 🚀 c9dab7d torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/wesee.yaml', device='', entity=None, epochs=10, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='wesee7_ind1_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/wesee7_ind1_2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training wesee newparsed cont..
# !python train.py  --epoch 40 --data data/wesee.yaml --weights wesee7_ind1.pt --name wesee7_ind2_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 678b806 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/wesee.yaml', device='', entity=None, epochs=40, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='wesee7_ind2_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/wesee7_ind2_3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='wesee7_ind1.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training wesee newparsed cont..
# !python train.py  --epoch 100 --data data/wesee.yaml --weights wesee7_ind2.pt --name wesee7_ind3_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 ec162d4 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/wesee.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='wesee7_ind3_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/wesee7_ind3_', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='wesee7_ind2.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Wesee additional training
# !python train.py  --epoch 60 --data data/wesee.yaml --weights wesee7_ind3.pt --name wesee7_ind4_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 73bef02 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/wesee.yaml', device='', entity=None, epochs=60, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='wesee7_ind4_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/wesee7_ind4_2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='wesee7_ind3.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Wesee additional training
# !python train.py  --epoch 60 --data data/wesee.yaml --weights wesee7_4.pt --name wesee7_ind5_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 1c71294 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(weights='wesee7_4.pt', cfg='cfg/training/yolov7.yaml', data='data/wesee.yaml', hyp='data/hyp.scratch.voyager.yaml', epochs=60, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='wesee7_ind5_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', world_size=1, global_rank=-1, save_dir='runs/train/wesee7_ind5_3', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Light only training
# !python train.py  --epoch 60 --data data/wesee_clear.yaml --weights wesee7_5.pt --name wesee7_ind6_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 1c71294 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(weights='wesee7_5.pt', cfg='cfg/training/yolov7.yaml', data='data/wesee_clear.yaml', hyp='data/hyp.scratch.voyager.yaml', epochs=60, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='wesee7_ind6_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', world_size=1, global_rank=-1, save_dir='runs/train/wesee7_ind6_', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# ## 2. Chair set

# %%
# First training chair newparsed
# !python train.py  --epoch 10 --data data/chair.yaml --weights yolov7.pt --name chair7_ind1_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 32
# Out:
# YOLOR 🚀 678b806 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/chair.yaml', device='', entity=None, epochs=10, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='chair7_ind1_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/chair7_ind1_', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training chair newparsed cont...
# !python train.py  --epoch 50 --data data/chair.yaml --weights chair7_ind1.pt --name chair7_ind2_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 32
# Out:
# YOLOR 🚀 ec162d4 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/chair.yaml', device='', entity=None, epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='chair7_ind2_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/chair7_ind2_', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='chair7_ind1.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training chair newparsed cont...
# !python train.py  --epoch 50 --data data/chair.yaml --weights chair7_ind2.pt --name chair7_ind3_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 6e9ef8d torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/chair.yaml', device='', entity=None, epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='chair7_ind3_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/chair7_ind3_', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='chair7_ind2.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training chair newparsed cont...
# !python train.py  --epoch 40 --data data/chair.yaml --weights chair7_ind3.pt --name chair7_ind4_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 0865ee6 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/chair.yaml', device='', entity=None, epochs=40, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='chair7_ind4_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/chair7_ind4_2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='chair7_ind3.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training chair newparsed cont...
# !python train.py  --epoch 30 --data data/chair.yaml --weights last.pt --name chair7_ind5_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 0865ee6 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/chair.yaml', device='', entity=None, epochs=30, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='chair7_ind5_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/chair7_ind5_6', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='last.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# ## 3. Dobo set

# %%
# First training dobo newparsed
# !python train.py  --epoch 10 --data data/dobo.yaml --weights yolov7.pt --name dobo7_ind1_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 32
# Out:
# YOLOR 🚀 ec162d4 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/dobo.yaml', device='', entity=None, epochs=10, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='dobo7_ind1_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/dobo7_ind1_2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training dobo newparsed cont...
# !python train.py  --epoch 50 --data data/dobo.yaml --weights dobo7_ind1.pt --name dobo7_ind2_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 2f4bf4e torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/dobo.yaml', device='', entity=None, epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='dobo7_ind2_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/dobo7_ind2_2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='dobo7_ind1.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training dobo newparsed cont...
# !python train.py  --epoch 2 --data data/dobo.yaml --weights last.pt --name dobo7_ind2_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 d10820f torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/dobo.yaml', device='', entity=None, epochs=2, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='dobo7_ind2_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/dobo7_ind2_3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='last.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training dobo newparsed cont...
# !python train.py  --epoch 20 --data data/dobo.yaml --weights dobo7_ind2.pt --name dobo7_ind3_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 75bab7d torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/dobo.yaml', device='', entity=None, epochs=20, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='dobo7_ind3_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/dobo7_ind3_2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='dobo7_ind2.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# ## 4. Barrier Set

# %%
# Training Barrier after ablation studies
# !python train.py  --epoch 40 --data data/barrier.yaml --weights barrier_ind2.pt --name barrier_ind2_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 75bab7d torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/barrier.yaml', device='', entity=None, epochs=40, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='barrier_ind2_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/barrier_ind2_4', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='barrier_ind2.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# Training Barrier after ablation studies
# !python train.py  --epoch 40 --data data/barrier.yaml --weights barrier7_ind2.pt --name barrier_ind3_ --img 640 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.voyager.yaml --batch-size 16
# Out:
# YOLOR 🚀 0865ee6 torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/barrier.yaml', device='', entity=None, epochs=40, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.voyager.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='barrier_ind3_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/barrier_ind3_', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='barrier7_ind2.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python3 detect.py
# Out:
# Traceback (most recent call last):
#   File "detect.py", line 10, in <module>
#     from models.experimental import attempt_load
#   File "/home/soma1/MVP/voyager-Vision-task/my_yolov7/models/experimental.py", line 6, in <module>
#     from models.common import Conv, DWConv
#   File "/home/soma1/MVP/voyager-Vision-task/my_yolov7/models/common.py", line 6, in <module>
#     import pandas as pd
#   File "/home/soma1/.local/lib/python3.8/site-packages/pandas/__init__.py", line 48, in <module>
#     from pandas.core.api import (
#   File "/home/soma1/.local/lib/python3.8/site-packages/pandas/core/api.py", line 22, in <module>
#     from pandas.core.algorithms import (
#   File "/home/soma1/.local/lib/python3.8/site-packages/pandas/core/algorithms.py", line 39, in <module>
#     from pandas.core.dtypes.cast import (
#   File "/home/soma1/.local/lib/python3.8/site-packages/pandas/core/dtypes/cast.py", line 24, in <module>
#     from dateutil.parser import ParserError
# ...
